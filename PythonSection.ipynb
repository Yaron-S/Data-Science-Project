# %% [markdown]
# # Data Science Final Project Code Section

# %% [markdown]
# ## Code

# %%
def DecimalToBinary(num):     
    if num > 1: 
        DecimalToBinary(num // 2) 
    print(num % 2, end = '') 
def DecimalToOctal(num):
    octalNum = [0] * 100
    i = 0
    while (num != 0):
        octalNum[i] = n % 8
        num = int(n / 8)
        i += 1
    for j in range(i - 1, -1, -1):
        print(octalNum[j], end="")

# %% [markdown]
# ## Pandas and Numpy

# %%
import pandas as pd
import numpy as np
cast = pd.read_csv('C:\\Users\\asus21\\Desktop\\cast.csv')
cast.head()
# Out:
#                                title  year       name   type character     n
# 0                    Suuri illusioni  1985     Homo $  actor    Guests  22.0
# 1     Gangsta Rap: The Glockumentary  2007  Too $hort  actor   Himself   NaN
# 2                  Menace II Society  1993  Too $hort  actor   Lew-Loc  27.0
# 3  Porndogs: The Adventures of Sadie  2009  Too $hort  actor     Bosco   3.0
# 4                 Stop Pepper Palmer  2014  Too $hort  actor   Himself   NaN

# %% [markdown]
# ## 1

# %%
cast.loc[cast['title']=='Hamlet'].count()
# Out:
# title        299
# year         299
# name         299
# type         299
# character    299
# n            234
# dtype: int64

# %% [markdown]
# ## 2

# %%
cast1 = cast.loc[cast['title']=='Treasure Island']
cast1.sort_values(by='year')
# Out:
#                    title  year                  name     type  \
# 1312766  Treasure Island  1918       Herschel Mayall    actor
# 3280557  Treasure Island  1918    Eleanor Washington  actress
# 3046750  Treasure Island  1918      Violet Radcliffe  actress
# 1167783  Treasure Island  1918           Raymond Lee    actor
# 1195421  Treasure Island  1918          Elmo Lincoln    actor
# ...                  ...   ...                   ...      ...
# 1663860  Treasure Island  1999  Victor Raider-Wexler    actor
# 1731182  Treasure Island  1999  Scot Thomas Robinson    actor
# 1813707  Treasure Island  1999        Richard Schave    actor
# 2710458  Treasure Island  1999    Stephanie Ittleson  actress
# 815338   Treasure Island  1999          Rio Hackford    actor
#
#                 character     n
# 1312766   Prologue Player   NaN
# 3280557   Prologue Player   NaN
# 3046750  Long John Silver   3.0
# 1167783          Bit Role   NaN
# 1195421   Prologue Player   NaN
# ...

# %% [markdown]
# ## 3

# %%
cast2 = cast.loc[cast['title']=='Hamlet'] 
c =cast2.loc[cast2['year']==1921].count()
c
# Out:
# title        9
# year         9
# name         9
# type         9
# character    9
# n            9
# dtype: int64

# %% [markdown]
# ## 4

# %%
g=cast.groupby('title')
h = g.get_group('Hamlet')
h.groupby(h.year // 10 * 10).size().plot(kind='bar')

# %% [markdown]
# ## 5

# %%
#5
cast1950 = cast[cast.year // 10 == 195]
cast1950 = cast1950[cast1950.n == 1]
cast1950.groupby(['year', 'type']).size()
# Out:
# year  type
# 1950  actor      604
#       actress    271
# 1951  actor      633
#       actress    272
# 1952  actor      591
#       actress    284
# 1953  actor      634
#       actress    290
# 1954  actor      626
#       actress    298
# 1955  actor      606
#       actress    264
# 1956  actor      614
#       actress    288
# 1957  actor      708
#       actress    284
# 1958  actor      694
#       actress    275
# 1959  actor      678
#       actress    287
# dtype: int64

# %% [markdown]
# ## 6

# %%
cast3 = cast.loc[cast['n']==1].loc[cast['year'] > 1990]
cast3.groupby('name').size().nlargest(10)
# Out:
# name
# Mohanlal              116
# Mammootty             105
# Akshay Kumar           87
# Jayaram                74
# Ajay Devgn             69
# Andy Lau               68
# Eric Roberts           67
# Amitabh Bachchan       66
# Dilip                  59
# Nagarjuna Akkineni     59
# dtype: int64

# %% [markdown]
# ## 7

# %%
cast4 = cast.loc[cast['n']>1] 
Oz = cast4.loc[cast['name']=='Frank Oz'] 
Oz.sort_values(by='year')
# Out:
#                                                   title  year      name  \
# 1538820                                The Muppet Movie  1979  Frank Oz
# 1538827                                The Muppet Movie  1979  Frank Oz
# 1538826                                The Muppet Movie  1979  Frank Oz
# 1538825                                The Muppet Movie  1979  Frank Oz
# 1538824                                The Muppet Movie  1979  Frank Oz
# 1538823                                The Muppet Movie  1979  Frank Oz
# 1538822                                The Muppet Movie  1979  Frank Oz
# 1538821                                The Muppet Movie  1979  Frank Oz
# 1538804                              The Blues Brothers  1980  Frank Oz
# 1538798  Star Wars: Episode V - The Empire Strikes Back  1980  Frank Oz
# 1538812                          The Great Muppet Caper  1981  Frank Oz
# 1538811                          The Great Muppet Caper  1981  Frank Oz
# ...
